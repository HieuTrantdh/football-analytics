# %%
import pandas as pd
import matplotlib.pyplot as plt
import mysql.connector
print("Tất cả thư viện OK!")
# Out:
# Tất cả thư viện OK!

# %%
import mysql.connector
import pandas as pd

try:
    conn = mysql.connector.connect(
        host="localhost",
        user="root",
        password="12345678",
        database="classicmodels"
    )
    # Các dòng dưới đây phải thụt lề bằng nhau:
    df = pd.read_sql("SELECT COUNT(*) as total FROM `customers`", conn)
    print("Kết nối DB thành công!")
    print(df)
except Exception as e:
    print(f"Lỗi rồi: {e}")
# Out:
# Kết nối DB thành công!
#    total
# 0    122
# /var/folders/kk/vmn6b97x3tj8hfvkn7x2vrqm0000gn/T/ipykernel_27250/2219130206.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT COUNT(*) as total FROM `customers`", conn)

# %%
df_test = pd.DataFrame({"Bảng": ["Match","Player","Team"], "Số dòng": [25000, 11000, 300]})
df_test.plot(kind="bar", x="Bảng", y="Số dòng", title="Test biểu đồ")
plt.show()
